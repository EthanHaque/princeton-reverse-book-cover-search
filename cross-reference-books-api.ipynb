# %%
import json
import queue
import re
from concurrent.futures import ThreadPoolExecutor

import requests
from tqdm.notebook import tqdm

# %%
with open('./data/book-test-set/book_covers.json', 'r', encoding="utf-8") as f:
    book_covers_data = json.load(f)

# %%
class BookCover:
    def __init__(self, json_object):
        self.image_name = json_object['image_name']
        self.pages_with_matching_images = json_object['custom_annotations']['pages_with_matching_images']
        self.full_matching_images = json_object['custom_annotations']['full_matching_images']
        self.partial_matching_images = json_object['custom_annotations']['partial_matching_images']
        self.web_entities = json_object['custom_annotations']['web_entities']

    def get_possible_titles(self):
        # TODO: make a better implementation
        return [(web_entity['description'], web_entity['score']) for web_entity in self.web_entities]

    def __str__(self):
        return json.dumps(self.__dict__(), indent=4)

    def __repr__(self):
        return self.__str__()

    def __dict__(self):
        outDict = {
            'image_name': self.image_name,
            'pages_with_matching_images': self.pages_with_matching_images,
            'full_matching_images': self.full_matching_images,
            'partial_matching_images': self.partial_matching_images,
            'web_entities': self.web_entities
        }
        return outDict

# %%
book_covers = [BookCover(book_cover) for book_cover in book_covers_data['book_covers']]

# %%
class BooksAPIObj:
    def __init__(self, book_cover):
        self.book_cover = book_cover
        self.google_book_data = self.get_google_book_data_for_book_cover()

    def get_images(self, urls):
        """Downloads images from the internet"""
        images = []
        for url in urls:
            response = requests.get(url)
            images.append(response.content)
        return images

    def download_partial_matching_images(self):
        """Downloads partial matching images from the internet"""
        return self.get_images(self.get_partial_matching_images())

    def download_full_matching_images(self):
        """Downloads full matching images from the internet"""
        return self.get_images(self.get_full_matching_images())

    def get_partial_matching_images(self):
        """Returns a list of urls of images that are partial matches"""
        return self.book_cover.partial_matching_images

    def get_full_matching_images(self):
        """Returns a list of urls of images that are full matches"""
        return self.book_cover.full_matching_images

    def get_pages_with_matching_images(self):
        """Returns a list of pages that have images that match the book cover"""
        return self.book_cover.pages_with_matching_images

    def clean_title(self, title):
        """Cleans the characters in the title to make it more suitable for searching"""
        cleaned = re.sub(r'[^0-9a-zA-Z ]', '', title)
        cleaned = re.sub(r'\s+', '+', cleaned)
        return cleaned

    def get_google_book_data(self, title):
        """Gets the google book data for a given title"""
        url = f'https://www.googleapis.com/books/v1/volumes?q=:{title}&orderBy=relevance&maxResults=3'
        response = requests.get(url)
        return response.json()

    def get_most_popular_titles(self, num_titles=3):
        """Gets the most popular titles from the book cover"""
        titles = []
        for title, score in self.book_cover.get_possible_titles():
            cleaned_title = self.clean_title(title)
            titles.append((cleaned_title, score))
        titles = sorted(titles, key=lambda x: x[1], reverse=True)
        return [title for title, score in titles[:num_titles]]

    def get_google_book_data_for_titles(self, titles):
        """Gets the google book data for a list of titles"""
        google_book_data = {}
        for title in titles:
            google_book_data[title] = self.get_google_book_data(title)
        return google_book_data

    def get_google_book_data_for_book_cover(self):
        """Gets the google book data for the book cover"""
        titles = self.get_most_popular_titles()
        return self.get_google_book_data_for_titles(titles)

    def save_partial_matching_images(self, image_output_dir):
        """Saves the partial matching images to the image output directory"""
        for i, image in enumerate(self.partial_matching_images):
            with open(f'{image_output_dir}/partial_matching_image_{self.book_cover.image_name}_{i}.jpg', 'wb') as f:
                f.write(image)

    def write_to_file(self, filename):
        """Writes the object to a file"""
        with open(filename, 'w') as f:
            json.dump(self.__dict__(), f, indent=4)

    def save_full_matching_images(self, image_output_dir):
        """Saves the full matching images to the image output directory"""
        for i, image in enumerate(self.full_matching_images):
            with open(f'{image_output_dir}/full_matching_image_{self.book_cover.image_name}_{i}.jpg', 'wb') as f:
                f.write(image)

    def __str__(self):
        return json.dumps(self.__dict__(), indent=4)

    def __repr__(self):
        return self.__str__()

    def __dict__(self):
        outDict = {
            'book_cover': self.book_cover.__dict__(),
            'google_book_data': self.google_book_data,
        }
        return outDict

# %%
results = queue.Queue()
with (tqdm(total=len(book_covers))) as pbar:
    with ThreadPoolExecutor(max_workers=8) as executor:
        for _ in executor.map(BooksAPIObj, book_covers):
            results.put(_)
            pbar.update(1)

results_list = list(results.queue)
# Out:
#   0%|          | 0/480 [00:00<?, ?it/s]

# %%
print(results_list[0])
# Out:
# {
#     "book_cover": {
#         "image_name": "user1433_1806_book_1_3.jpg",
#         "pages_with_matching_images": [
#             "https://books.disney.com/book/lightning-thief-the/",
#             "https://foreveryoungadult.com/2013/05/31/book-vs-movie-the-lightning-thief/",
#             "https://www.bookseriesrecaps.com/what-happened-in-the-lightning-thief/",
#             "https://www.walmart.com/ip/The-Lightning-Thief-Paperback-9780786838653/4406976",
#             "https://ppld.org/book-reviews/lightning-thief-3",
#             "https://ppld.org/book-reviews/lightning-thief-6",
#             "https://ppld.org/book-reviews/lightning-thief-2",
#             "https://boysbookblog.wordpress.com/2011/02/10/opening-lines-stories-that-grab-you-at-go/",
#             "https://time.com/collection/100-best-ya-books/6084700/the-lightning-thief/",
#             "https://fb2bookfree.com/adventure/3374-the-lightning-thief.html"
#         ],
#         "full_matching_images": [],
#         "partial_matching_images": [
#             "https://nikihawkes.files.wordpress.com/2013/03/a13.jpg?w=106&h=160",
#             "https://img.wattpad.com/cover/1549620-160-k327258.jpg",
#             "https://www.cache2net2.com//Repositorio/5286/Produtos/88c4a99a-d.jpg",
#             "https://assets.mycast.io/posters/percy-jackson-tv-series-season-1-fan-casting-poster-41730-medium.jpg?1591841205",
#             "https://bibliomavens.files.wordpress.com/2020/07/screen-shot-2020-07-22-at-10.50.14-am.png",
#             "https://librarianarika.files.wordpress.com/2015/03/the-lightning-thief-book-cover.jpg?w=102&h=150",
#             "https://jspinkmills.files.wordpress.com/2017/06/2017-06-09-16-34-57.jpg?w=114&h=152",
#             "https://img.wattpad.com/cover/276292439-256-k561663.jpg",
#             "https://static.wixstatic.com/media/81db8d_b34bb11e49fe4471a4c439301b3512ab~mv2.jpg/v1/fit/w_320%2Ch_700%2Cal_c%2Cq_80/file.jpg",
#             "https://images.isbndb.com/covers/62/99/9780786856299.jpg"
#         ],
#         "web_entities": [
#             {
#                 "score": 1.3165500164031982,
#                 "description": "Percy Jackson & the Olympians: The Lightning Thief"
#             },
#             {
#                 "score": 0.8755500316619873,
#                 "description": "Percy Jackson and the Lightning Thief - The Graphic Novel (Book 1 of Percy Jackson)"
#             },
#             {
#                 "score": 0.7272999882698059,
#                 "description": "Percy Jackson & the Olympians"
#             },
#             {
#                 "score": 0.7105000019073486,
#                 "description": "Book"
#             },
#             {
#                 "score": 0.5940999984741211,
#                 "description": "Novel"
#             },
#             {
#                 "score": 0.5218499898910522,
#                 "description": "The Battle of the Labyrinth"
#             },
#             {
#                 "score": 0.491100013256073,
#                 "description": "Hachette Books"
#             },
#             {
#                 "score": 0.48240000009536743,
#                 "description": "Ebook"
#             },
#             {
#                 "score": 0.45489999651908875,
#                 "description": "Reading"
#             },
#             {
#                 "score": 0.43459999561309814,
#                 "description": "Miramax Books"
#             }
#         ]
#     },
#     "google_book_data": {
#         "Percy+Jackson+the+Olympians+The+Lightning+Thief": {
#             "kind": "books#volumes",
#             "totalItems": 964,
#             "items": [
#                 {
#                     "kind": "books#volume",
#                     "id": "FFTJDYx_ZiEC",
#                     "etag": "KbeuCUaBwF0",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/FFTJDYx_ZiEC",
#                     "volumeInfo": {
#                         "title": "Lightning Thief, The (Percy Jackson and the Olympians, Book 1)",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Disney Electronic Content",
#                         "publishedDate": "2009-05-02",
#                         "description": "Percy Jackson is a good kid, but he can't seem to focus on his schoolwork or control his temper. And lately, being away at boarding school is only getting worse-Percy could have sworn his pre-algebra teacher turned into a monster and tried to kill him.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423131892"
#                             },
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423131894"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": true,
#                             "image": false
#                         },
#                         "pageCount": 400,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 4,
#                         "ratingsCount": 838,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": true,
#                         "contentVersion": "0.41.40.0.preview.2",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=FFTJDYx_ZiEC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=FFTJDYx_ZiEC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=FFTJDYx_ZiEC&printsec=frontcover&dq=:Percy+Jackson+the+Olympians+The+Lightning+Thief&hl=&cd=1&source=gbs_api",
#                         "infoLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC&source=gbs_api",
#                         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "FOR_SALE",
#                         "isEbook": true,
#                         "listPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "retailPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "buyLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC&rdid=book-FFTJDYx_ZiEC&rdot=1&source=gbs_api",
#                         "offers": [
#                             {
#                                 "finskyOfferType": 1,
#                                 "listPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "retailPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "giftable": true
#                             }
#                         ]
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "PARTIAL",
#                         "embeddable": true,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Lightning_Thief_The_Percy_Jackson_and_th-sample-epub.acsm?id=FFTJDYx_ZiEC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=FFTJDYx_ZiEC&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "SAMPLE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "Percy Jackson is a good kid, but he can&#39;t seem to focus on his schoolwork or control his temper."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "Jcb-swEACAAJ",
#                     "etag": "3hD5C8CTJxM",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/Jcb-swEACAAJ",
#                     "volumeInfo": {
#                         "title": "Percy Jackson and the Olympians The Lightning Thief Illustrated Edition",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Disney-Hyperion",
#                         "publishedDate": "2018-08-14",
#                         "description": "Percy Jackson is about to be kicked out of boarding school . . . again. And that's the least of his troubles. Lately, mythological monsters and the gods of Mount Olympus seem to be walking straight out of the pages of Percy's Greek mythology textbook and into his life. And worse, he's angered a few of them. Zeus's master lightning bolt has been stolen, and Percy is the prime suspect. Now Percy and his friends have just ten days to find and return Zeus's stolen property and bring peace to a warring Mount Olympus. But to succeed on his quest, Percy will have to do more than catch the true thief: he must come to terms with the father who abandoned him; solve the riddle of the Oracle, which warns him of betrayal by a friend; and unravel a treachery more powerful than the gods themselves. This deluxe gift edition of the internationally best-selling first book in the Percy Jackson and the Olympians series, lavishly illustrated by series artist John Rocco, is a must-have for Riordan fans.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1484787781"
#                             },
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781484787786"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": false,
#                             "image": false
#                         },
#                         "pageCount": 240,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 5,
#                         "ratingsCount": 2,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": false,
#                         "contentVersion": "preview-1.0.0",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=Jcb-swEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=Jcb-swEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=Jcb-swEACAAJ&dq=:Percy+Jackson+the+Olympians+The+Lightning+Thief&hl=&cd=2&source=gbs_api",
#                         "infoLink": "http://books.google.com/books?id=Jcb-swEACAAJ&dq=:Percy+Jackson+the+Olympians+The+Lightning+Thief&hl=&source=gbs_api",
#                         "canonicalVolumeLink": "https://books.google.com/books/about/Percy_Jackson_and_the_Olympians_The_Ligh.html?hl=&id=Jcb-swEACAAJ"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "NOT_FOR_SALE",
#                         "isEbook": false
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "NO_PAGES",
#                         "embeddable": false,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": false
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=Jcb-swEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "NONE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "This deluxe gift edition of the internationally best-selling first book in the Percy Jackson and the Olympians series, lavishly illustrated by series artist John Rocco, is a must-have for Riordan fans."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "b2Wtjqjy8CwC",
#                     "etag": "OC7pVXvYu+I",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/b2Wtjqjy8CwC",
#                     "volumeInfo": {
#                         "title": "Percy Jackson and the Olympians: The Lightning Thief: The Graphic Novel",
#                         "authors": [
#                             "Rick Riordan",
#                             "Robert Venditti"
#                         ],
#                         "publisher": "Disney Electronic Content",
#                         "publishedDate": "2013-07-02",
#                         "description": "You've read the book. You've seen the movie. Now submerge yourself in the thrilling, stunning, and action-packed graphic novel. Mythological monsters and the gods of Mount Olympus seem to be walking out of the pages of twelve-year-old Percy Jackson's textbooks and into his life. And worse, he's angered a few of them. Zeus's master lightning bolt has been stolen, and Percy is the prime suspect. Now, he and his friends have just ten days to find and return Zeus's stolen property and bring peace to a warring Mount Olympus. Series creator Rick Riordan joins forces with some of the biggest names in the comic book industry to tell the story of a boy who must unravel a treachery more powerful than the gods themselves.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423147343"
#                             },
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423147340"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": true,
#                             "image": true
#                         },
#                         "pageCount": 128,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 3,
#                         "ratingsCount": 2,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": true,
#                         "contentVersion": "1.6.8.0.preview.3",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=b2Wtjqjy8CwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=b2Wtjqjy8CwC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=b2Wtjqjy8CwC&printsec=frontcover&dq=:Percy+Jackson+the+Olympians+The+Lightning+Thief&hl=&cd=3&source=gbs_api",
#                         "infoLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC&source=gbs_api",
#                         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC",
#                         "seriesInfo": {
#                             "kind": "books#volume_series_info",
#                             "bookDisplayNumber": "1",
#                             "volumeSeries": [
#                                 {
#                                     "seriesId": "ZaIqGwAAABBOuM",
#                                     "seriesBookType": "COLLECTED_EDITION",
#                                     "orderNumber": 1
#                                 }
#                             ]
#                         }
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "FOR_SALE",
#                         "isEbook": true,
#                         "listPrice": {
#                             "amount": 7.99,
#                             "currencyCode": "USD"
#                         },
#                         "retailPrice": {
#                             "amount": 7.99,
#                             "currencyCode": "USD"
#                         },
#                         "buyLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC&rdid=book-b2Wtjqjy8CwC&rdot=1&source=gbs_api",
#                         "offers": [
#                             {
#                                 "finskyOfferType": 1,
#                                 "listPrice": {
#                                     "amountInMicros": 7990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "retailPrice": {
#                                     "amountInMicros": 7990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "giftable": true
#                             }
#                         ]
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "PARTIAL",
#                         "embeddable": true,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Percy_Jackson_and_the_Olympians_The_Ligh-sample-epub.acsm?id=b2Wtjqjy8CwC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "pdf": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Percy_Jackson_and_the_Olympians_The_Ligh-sample-pdf.acsm?id=b2Wtjqjy8CwC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=b2Wtjqjy8CwC&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "SAMPLE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "You&#39;ve read the book."
#                     }
#                 }
#             ]
#         },
#         "Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson": {
#             "kind": "books#volumes",
#             "totalItems": 569,
#             "items": [
#                 {
#                     "kind": "books#volume",
#                     "id": "UevuQwAACAAJ",
#                     "etag": "ujjTKBT+A9U",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/UevuQwAACAAJ",
#                     "volumeInfo": {
#                         "title": "The Percy Jackson and the Olympians: Lightning Thief: The Graphic Novel",
#                         "authors": [
#                             "Rick Riordan",
#                             "Robert Venditti"
#                         ],
#                         "publisher": "Hyperion",
#                         "publishedDate": "2010-10-12",
#                         "description": "You've read the book. You've seen the movie. Now submerge yourself in the thrilling, stunning, and action-packed graphic novel. Mythological monsters and the gods of Mount Olympus seem to be walking out of the pages of twelve-year-old Percy Jackson's textbooks and into his life. And worse, he's angered a few of them. Zeus's master lightning bolt has been stolen, and Percy is the prime suspect. Now, he and his friends have just ten days to find and return Zeus's stolen property and bring peace to a warring Mount Olympus. Series creator Rick Riordan joins forces with some of the biggest names in the comic book industry to tell the story of a boy who must unravel a treachery more powerful than the gods themselves.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423117107"
#                             },
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423117100"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": false,
#                             "image": false
#                         },
#                         "pageCount": 128,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 5,
#                         "ratingsCount": 1,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": false,
#                         "contentVersion": "preview-1.0.0",
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=UevuQwAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=UevuQwAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=UevuQwAACAAJ&dq=:Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson&hl=&cd=1&source=gbs_api",
#                         "infoLink": "http://books.google.com/books?id=UevuQwAACAAJ&dq=:Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson&hl=&source=gbs_api",
#                         "canonicalVolumeLink": "https://books.google.com/books/about/The_Percy_Jackson_and_the_Olympians_Ligh.html?hl=&id=UevuQwAACAAJ"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "NOT_FOR_SALE",
#                         "isEbook": false
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "NO_PAGES",
#                         "embeddable": false,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": false
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=UevuQwAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "NONE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "You&#39;ve read the book."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "b2Wtjqjy8CwC",
#                     "etag": "9dLvWn9sSIc",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/b2Wtjqjy8CwC",
#                     "volumeInfo": {
#                         "title": "Percy Jackson and the Olympians: The Lightning Thief: The Graphic Novel",
#                         "authors": [
#                             "Rick Riordan",
#                             "Robert Venditti"
#                         ],
#                         "publisher": "Disney Electronic Content",
#                         "publishedDate": "2013-07-02",
#                         "description": "You've read the book. You've seen the movie. Now submerge yourself in the thrilling, stunning, and action-packed graphic novel. Mythological monsters and the gods of Mount Olympus seem to be walking out of the pages of twelve-year-old Percy Jackson's textbooks and into his life. And worse, he's angered a few of them. Zeus's master lightning bolt has been stolen, and Percy is the prime suspect. Now, he and his friends have just ten days to find and return Zeus's stolen property and bring peace to a warring Mount Olympus. Series creator Rick Riordan joins forces with some of the biggest names in the comic book industry to tell the story of a boy who must unravel a treachery more powerful than the gods themselves.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423147343"
#                             },
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423147340"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": true,
#                             "image": true
#                         },
#                         "pageCount": 128,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 3,
#                         "ratingsCount": 2,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": true,
#                         "contentVersion": "1.6.8.0.preview.3",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=b2Wtjqjy8CwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=b2Wtjqjy8CwC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=b2Wtjqjy8CwC&printsec=frontcover&dq=:Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson&hl=&cd=2&source=gbs_api",
#                         "infoLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC&source=gbs_api",
#                         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC",
#                         "seriesInfo": {
#                             "kind": "books#volume_series_info",
#                             "bookDisplayNumber": "1",
#                             "volumeSeries": [
#                                 {
#                                     "seriesId": "ZaIqGwAAABBOuM",
#                                     "seriesBookType": "COLLECTED_EDITION",
#                                     "orderNumber": 1
#                                 }
#                             ]
#                         }
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "FOR_SALE",
#                         "isEbook": true,
#                         "listPrice": {
#                             "amount": 7.99,
#                             "currencyCode": "USD"
#                         },
#                         "retailPrice": {
#                             "amount": 7.99,
#                             "currencyCode": "USD"
#                         },
#                         "buyLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC&rdid=book-b2Wtjqjy8CwC&rdot=1&source=gbs_api",
#                         "offers": [
#                             {
#                                 "finskyOfferType": 1,
#                                 "listPrice": {
#                                     "amountInMicros": 7990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "retailPrice": {
#                                     "amountInMicros": 7990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "giftable": true
#                             }
#                         ]
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "PARTIAL",
#                         "embeddable": true,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Percy_Jackson_and_the_Olympians_The_Ligh-sample-epub.acsm?id=b2Wtjqjy8CwC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "pdf": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Percy_Jackson_and_the_Olympians_The_Ligh-sample-pdf.acsm?id=b2Wtjqjy8CwC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=b2Wtjqjy8CwC&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "SAMPLE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "You&#39;ve read the book."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "e3_VPwAACAAJ",
#                     "etag": "crmMd+OS5nQ",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/e3_VPwAACAAJ",
#                     "volumeInfo": {
#                         "title": "Percy Jackson and the Lightning Thief",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Puffin Books",
#                         "publishedDate": "2009-12-01",
#                         "description": "Look, I didn't want to be a half-blood. I never asked to be the son of a Greek god. I was just a normal kid, going to school, playing basketball, skateboarding. The usual. Until I accidentally vaporized my maths teacher. That's when things started really going wrong. Now I spend my time fighting with swords, battling monsters with my friends and generally trying to stay alive. This is the one where Zeus, God of the Sky, thinks I've stolen his lightning bolt - and making Zeus angry is a very bad idea. Can Percy find the lightning bolt before a fully fledged WAR OF THE GODS ERUPTS? Follow the author on his blog Also available: Percy Jackson and the Battle of the Labyrinth Percy Jackson and the Last Olympian Percy Jackson and the Lightning Thief (audio) Percy Jackson and the Lightning Thief (film tie-in) Percy Jackson and the Sea of Monsters Percy Jackson and the Titan's Curse Percy Jackson: The Demigod Files",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "0141329998"
#                             },
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9780141329994"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": false,
#                             "image": false
#                         },
#                         "pageCount": 374,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Children's stories"
#                         ],
#                         "averageRating": 4,
#                         "ratingsCount": 688,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": false,
#                         "contentVersion": "preview-1.0.0",
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=e3_VPwAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=e3_VPwAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=e3_VPwAACAAJ&dq=:Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson&hl=&cd=3&source=gbs_api",
#                         "infoLink": "http://books.google.com/books?id=e3_VPwAACAAJ&dq=:Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson&hl=&source=gbs_api",
#                         "canonicalVolumeLink": "https://books.google.com/books/about/Percy_Jackson_and_the_Lightning_Thief.html?hl=&id=e3_VPwAACAAJ"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "NOT_FOR_SALE",
#                         "isEbook": false
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "NO_PAGES",
#                         "embeddable": false,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": false
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=e3_VPwAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "NONE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "YA. Fantasy fiction."
#                     }
#                 }
#             ]
#         },
#         "Percy+Jackson+the+Olympians": {
#             "kind": "books#volumes",
#             "totalItems": 1152,
#             "items": [
#                 {
#                     "kind": "books#volume",
#                     "id": "LA-dKVg8alsC",
#                     "etag": "5SiAaLDz4hI",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/LA-dKVg8alsC",
#                     "volumeInfo": {
#                         "title": "Last Olympian, The (Percy Jackson and the Olympians, Book 5)",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Disney Electronic Content",
#                         "publishedDate": "2009-05-02",
#                         "description": "All year the half-bloods have been preparing for battle against the Titans, knowing the odds of victory are grim. Kronos's army is stronger than ever, and with every god and half-blood he recruits, the evil Titan's power only grows. While the Olympians struggle to contain the rampaging monster Typhon, Kronos begins his advance on New York City, where Mount Olympus stands virtually unguarded. Now it's up to Percy Jackson and an army of young demigods to stop the Lord of Time.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423131991"
#                             },
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423131991"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": true,
#                             "image": false
#                         },
#                         "pageCount": 416,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 4.5,
#                         "ratingsCount": 91,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": true,
#                         "contentVersion": "0.13.12.0.preview.2",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=LA-dKVg8alsC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=LA-dKVg8alsC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=LA-dKVg8alsC&printsec=frontcover&dq=:Percy+Jackson+the+Olympians&hl=&cd=1&source=gbs_api",
#                         "infoLink": "https://play.google.com/store/books/details?id=LA-dKVg8alsC&source=gbs_api",
#                         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=LA-dKVg8alsC"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "FOR_SALE",
#                         "isEbook": true,
#                         "listPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "retailPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "buyLink": "https://play.google.com/store/books/details?id=LA-dKVg8alsC&rdid=book-LA-dKVg8alsC&rdot=1&source=gbs_api",
#                         "offers": [
#                             {
#                                 "finskyOfferType": 1,
#                                 "listPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "retailPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "giftable": true
#                             }
#                         ]
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "PARTIAL",
#                         "embeddable": true,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Last_Olympian_The_Percy_Jackson_and_the-sample-epub.acsm?id=LA-dKVg8alsC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=LA-dKVg8alsC&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "SAMPLE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "All year the half-bloods have been preparing for battle against the Titans, knowing the odds of victory are grim."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "FFTJDYx_ZiEC",
#                     "etag": "kDkLApOqer8",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/FFTJDYx_ZiEC",
#                     "volumeInfo": {
#                         "title": "Lightning Thief, The (Percy Jackson and the Olympians, Book 1)",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Disney Electronic Content",
#                         "publishedDate": "2009-05-02",
#                         "description": "Percy Jackson is a good kid, but he can't seem to focus on his schoolwork or control his temper. And lately, being away at boarding school is only getting worse-Percy could have sworn his pre-algebra teacher turned into a monster and tried to kill him.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423131892"
#                             },
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423131894"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": true,
#                             "image": false
#                         },
#                         "pageCount": 400,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 4,
#                         "ratingsCount": 838,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": true,
#                         "contentVersion": "0.41.40.0.preview.2",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=FFTJDYx_ZiEC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=FFTJDYx_ZiEC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=FFTJDYx_ZiEC&printsec=frontcover&dq=:Percy+Jackson+the+Olympians&hl=&cd=2&source=gbs_api",
#                         "infoLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC&source=gbs_api",
#                         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "FOR_SALE",
#                         "isEbook": true,
#                         "listPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "retailPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "buyLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC&rdid=book-FFTJDYx_ZiEC&rdot=1&source=gbs_api",
#                         "offers": [
#                             {
#                                 "finskyOfferType": 1,
#                                 "listPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "retailPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "giftable": true
#                             }
#                         ]
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "PARTIAL",
#                         "embeddable": true,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Lightning_Thief_The_Percy_Jackson_and_th-sample-epub.acsm?id=FFTJDYx_ZiEC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=FFTJDYx_ZiEC&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "SAMPLE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "Percy Jackson is a good kid, but he can&#39;t seem to focus on his schoolwork or control his temper."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "Awv-nQEACAAJ",
#                     "etag": "bgQ+d3uHsIQ",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/Awv-nQEACAAJ",
#                     "volumeInfo": {
#                         "title": "Percy Jackson and the Olympians 5 Book Paperback Boxed Set (new covers w/poster)",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Disney-Hyperion",
#                         "publishedDate": "2014-06-03",
#                         "description": "All five books in the blockbuster Percy Jackson and the Olympians series, in paperback, have been collected in a boxed set fit for demigods. Now with glorious new cover art and packaged with a special poster, this value-priced set includes the best-selling The Lightning Thief, The Sea of Monsters, The Titan's Curse, The Battle of the Labyrinth, and The Last Olympian. Whether it is for readers who are experiencing Percy's thrilling adventures with Greek gods and monsters for the first time, or for fans who want to devour the saga again, this gift will be prized by young and old.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1484707230"
#                             },
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781484707234"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": false,
#                             "image": false
#                         },
#                         "pageCount": 1840,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": false,
#                         "contentVersion": "preview-1.0.0",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=Awv-nQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=Awv-nQEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=Awv-nQEACAAJ&dq=:Percy+Jackson+the+Olympians&hl=&cd=3&source=gbs_api",
#                         "infoLink": "http://books.google.com/books?id=Awv-nQEACAAJ&dq=:Percy+Jackson+the+Olympians&hl=&source=gbs_api",
#                         "canonicalVolumeLink": "https://books.google.com/books/about/Percy_Jackson_and_the_Olympians_5_Book_P.html?hl=&id=Awv-nQEACAAJ"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "NOT_FOR_SALE",
#                         "isEbook": false
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "NO_PAGES",
#                         "embeddable": false,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": false
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=Awv-nQEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "NONE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "All five books in the blockbuster Percy Jackson and the Olympians series, in paperback, have been collected in a boxed set fit for demigods."
#                     }
#                 }
#             ]
#         }
#     }
# }

# %%
integrated_book_covers = [response.__dict__() for response in results_list]
print('Writing to file...')
with open(r'./data/book-test-set/integrated_api_responses.json', 'w', encoding='utf-8') as outfile:
    # certain book titles have unicode characters in them, so we need to encode them as utf-8
    json.dump(integrated_book_covers, outfile, ensure_ascii=False, indent=4)
print('Done!')
# Out:
# Writing to file...
# Done!

# %%
first_book_cover = book_covers[0]
test = BooksAPIObj(first_book_cover)
# Out:
# {'Percy+Jackson+the+Olympians+The+Lightning+Thief': {'kind': 'books#volumes', 'totalItems': 963, 'items': [{'kind': 'books#volume', 'id': 'FFTJDYx_ZiEC', 'etag': 'tuem6tsBRWQ', 'selfLink': 'https://www.googleapis.com/books/v1/volumes/FFTJDYx_ZiEC', 'volumeInfo': {'title': 'Lightning Thief, The (Percy Jackson and the Olympians, Book 1)', 'authors': ['Rick Riordan'], 'publisher': 'Disney Electronic Content', 'publishedDate': '2009-05-02', 'description': "Percy Jackson is a good kid, but he can't seem to focus on his schoolwork or control his temper. And lately, being away at boarding school is only getting worse-Percy could have sworn his pre-algebra teacher turned into a monster and tried to kill him.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781423131892'}, {'type': 'ISBN_10', 'identifier': '1423131894'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 400, 'printType': 'BOOK', 'categories': ['Juvenile Fiction'], 'averageRating': 4, 'ratingsCount': 838, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': '0.41.40.0.preview.2', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=FFTJDYx_ZiEC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=FFTJDYx_ZiEC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=FFTJDYx_ZiEC&printsec=frontcover&dq=:Percy+Jackson+the+Olympians+The+Lightning+Thief&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=FFTJDYx_ZiEC&source=gbs_api', 'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=FFTJDYx_ZiEC'}, 'saleInfo': {'country': 'US', 'saleability': 'FOR_SALE', 'isEbook': True, 'listPrice': {'amount': 5.99, 'currencyCode': 'USD'}, 'retailPrice': {'amount': 5.99, 'currencyCode': 'USD'}, 'buyLink': 'https://play.google.com/store/books/details?id=FFTJDYx_ZiEC&rdid=book-FFTJDYx_ZiEC&rdot=1&source=gbs_api', 'offers': [{'finskyOfferType': 1, 'listPrice': {'amountInMicros': 5990000, 'currencyCode': 'USD'}, 'retailPrice': {'amountInMicros': 5990000, 'currencyCode': 'USD'}, 'giftable': True}]}, 'accessInfo': {'country': 'US', 'viewability': 'PARTIAL', 'embeddable': True, 'publicDomain': False, 'textToSpeechPermission': 'ALLOWED', 'epub': {'isAvailable': True, 'acsTokenLink': 'http://books.google.com/books/download/Lightning_Thief_The_Percy_Jackson_and_th-sample-epub.acsm?id=FFTJDYx_ZiEC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'}, 'pdf': {'isAvailable': False}, 'webReaderLink': 'http://play.google.com/books/reader?id=FFTJDYx_ZiEC&hl=&printsec=frontcover&source=gbs_api', 'accessViewStatus': 'SAMPLE', 'quoteSharingAllowed': False}, 'searchInfo': {'textSnippet': 'Percy Jackson is a good kid, but he can&#39;t seem to focus on his schoolwork or control his temper.'}}, {'kind': 'books#volume', 'id': 'Jcb-swEACAAJ', 'etag': 'QOBQ6kcJIck', 'selfLink': 'https://www.googleapis.com/books/v1/volumes/Jcb-swEACAAJ', 'volumeInfo': {'title': 'Percy Jackson and the Olympians The Lightning Thief Illustrated Edition', 'authors': ['Rick Riordan'], 'publisher': 'Disney-Hyperion', 'publishedDate': '2018-08-14', 'description': "Percy Jackson is about to be kicked out of boarding school . . . again. And that's the least of his troubles. Lately, mythological monsters and the gods of Mount Olympus seem to be walking straight out of the pages of Percy's Greek mythology textbook and into his life. And worse, he's angered a few of them. Zeus's master lightning bolt has been stolen, and Percy is the prime suspect. Now Percy and his friends have just ten days to find and return Zeus's stolen property and bring peace to a warring Mount Olympus. But to succeed on his quest, Percy will have to do more than catch the true thief: he must come to terms with th ...

# %%
print(test)
# Out:
# {
#     "book_cover": {
#         "image_name": "user1433_1806_book_1_3.jpg",
#         "pages_with_matching_images": [
#             "https://books.disney.com/book/lightning-thief-the/",
#             "https://foreveryoungadult.com/2013/05/31/book-vs-movie-the-lightning-thief/",
#             "https://www.bookseriesrecaps.com/what-happened-in-the-lightning-thief/",
#             "https://www.walmart.com/ip/The-Lightning-Thief-Paperback-9780786838653/4406976",
#             "https://ppld.org/book-reviews/lightning-thief-3",
#             "https://ppld.org/book-reviews/lightning-thief-6",
#             "https://ppld.org/book-reviews/lightning-thief-2",
#             "https://boysbookblog.wordpress.com/2011/02/10/opening-lines-stories-that-grab-you-at-go/",
#             "https://time.com/collection/100-best-ya-books/6084700/the-lightning-thief/",
#             "https://fb2bookfree.com/adventure/3374-the-lightning-thief.html"
#         ],
#         "full_matching_images": [],
#         "partial_matching_images": [
#             "https://nikihawkes.files.wordpress.com/2013/03/a13.jpg?w=106&h=160",
#             "https://img.wattpad.com/cover/1549620-160-k327258.jpg",
#             "https://www.cache2net2.com//Repositorio/5286/Produtos/88c4a99a-d.jpg",
#             "https://assets.mycast.io/posters/percy-jackson-tv-series-season-1-fan-casting-poster-41730-medium.jpg?1591841205",
#             "https://bibliomavens.files.wordpress.com/2020/07/screen-shot-2020-07-22-at-10.50.14-am.png",
#             "https://librarianarika.files.wordpress.com/2015/03/the-lightning-thief-book-cover.jpg?w=102&h=150",
#             "https://jspinkmills.files.wordpress.com/2017/06/2017-06-09-16-34-57.jpg?w=114&h=152",
#             "https://img.wattpad.com/cover/276292439-256-k561663.jpg",
#             "https://static.wixstatic.com/media/81db8d_b34bb11e49fe4471a4c439301b3512ab~mv2.jpg/v1/fit/w_320%2Ch_700%2Cal_c%2Cq_80/file.jpg",
#             "https://images.isbndb.com/covers/62/99/9780786856299.jpg"
#         ],
#         "web_entities": [
#             {
#                 "score": 1.3165500164031982,
#                 "description": "Percy Jackson & the Olympians: The Lightning Thief"
#             },
#             {
#                 "score": 0.8755500316619873,
#                 "description": "Percy Jackson and the Lightning Thief - The Graphic Novel (Book 1 of Percy Jackson)"
#             },
#             {
#                 "score": 0.7272999882698059,
#                 "description": "Percy Jackson & the Olympians"
#             },
#             {
#                 "score": 0.7105000019073486,
#                 "description": "Book"
#             },
#             {
#                 "score": 0.5940999984741211,
#                 "description": "Novel"
#             },
#             {
#                 "score": 0.5218499898910522,
#                 "description": "The Battle of the Labyrinth"
#             },
#             {
#                 "score": 0.491100013256073,
#                 "description": "Hachette Books"
#             },
#             {
#                 "score": 0.48240000009536743,
#                 "description": "Ebook"
#             },
#             {
#                 "score": 0.45489999651908875,
#                 "description": "Reading"
#             },
#             {
#                 "score": 0.43459999561309814,
#                 "description": "Miramax Books"
#             }
#         ]
#     },
#     "google_book_data": {
#         "Percy+Jackson+the+Olympians+The+Lightning+Thief": {
#             "kind": "books#volumes",
#             "totalItems": 963,
#             "items": [
#                 {
#                     "kind": "books#volume",
#                     "id": "FFTJDYx_ZiEC",
#                     "etag": "tuem6tsBRWQ",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/FFTJDYx_ZiEC",
#                     "volumeInfo": {
#                         "title": "Lightning Thief, The (Percy Jackson and the Olympians, Book 1)",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Disney Electronic Content",
#                         "publishedDate": "2009-05-02",
#                         "description": "Percy Jackson is a good kid, but he can't seem to focus on his schoolwork or control his temper. And lately, being away at boarding school is only getting worse-Percy could have sworn his pre-algebra teacher turned into a monster and tried to kill him.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423131892"
#                             },
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423131894"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": true,
#                             "image": false
#                         },
#                         "pageCount": 400,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 4,
#                         "ratingsCount": 838,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": true,
#                         "contentVersion": "0.41.40.0.preview.2",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=FFTJDYx_ZiEC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=FFTJDYx_ZiEC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=FFTJDYx_ZiEC&printsec=frontcover&dq=:Percy+Jackson+the+Olympians+The+Lightning+Thief&hl=&cd=1&source=gbs_api",
#                         "infoLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC&source=gbs_api",
#                         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "FOR_SALE",
#                         "isEbook": true,
#                         "listPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "retailPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "buyLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC&rdid=book-FFTJDYx_ZiEC&rdot=1&source=gbs_api",
#                         "offers": [
#                             {
#                                 "finskyOfferType": 1,
#                                 "listPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "retailPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "giftable": true
#                             }
#                         ]
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "PARTIAL",
#                         "embeddable": true,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Lightning_Thief_The_Percy_Jackson_and_th-sample-epub.acsm?id=FFTJDYx_ZiEC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=FFTJDYx_ZiEC&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "SAMPLE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "Percy Jackson is a good kid, but he can&#39;t seem to focus on his schoolwork or control his temper."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "Jcb-swEACAAJ",
#                     "etag": "QOBQ6kcJIck",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/Jcb-swEACAAJ",
#                     "volumeInfo": {
#                         "title": "Percy Jackson and the Olympians The Lightning Thief Illustrated Edition",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Disney-Hyperion",
#                         "publishedDate": "2018-08-14",
#                         "description": "Percy Jackson is about to be kicked out of boarding school . . . again. And that's the least of his troubles. Lately, mythological monsters and the gods of Mount Olympus seem to be walking straight out of the pages of Percy's Greek mythology textbook and into his life. And worse, he's angered a few of them. Zeus's master lightning bolt has been stolen, and Percy is the prime suspect. Now Percy and his friends have just ten days to find and return Zeus's stolen property and bring peace to a warring Mount Olympus. But to succeed on his quest, Percy will have to do more than catch the true thief: he must come to terms with the father who abandoned him; solve the riddle of the Oracle, which warns him of betrayal by a friend; and unravel a treachery more powerful than the gods themselves. This deluxe gift edition of the internationally best-selling first book in the Percy Jackson and the Olympians series, lavishly illustrated by series artist John Rocco, is a must-have for Riordan fans.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1484787781"
#                             },
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781484787786"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": false,
#                             "image": false
#                         },
#                         "pageCount": 240,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 5,
#                         "ratingsCount": 2,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": false,
#                         "contentVersion": "preview-1.0.0",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=Jcb-swEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=Jcb-swEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=Jcb-swEACAAJ&dq=:Percy+Jackson+the+Olympians+The+Lightning+Thief&hl=&cd=2&source=gbs_api",
#                         "infoLink": "http://books.google.com/books?id=Jcb-swEACAAJ&dq=:Percy+Jackson+the+Olympians+The+Lightning+Thief&hl=&source=gbs_api",
#                         "canonicalVolumeLink": "https://books.google.com/books/about/Percy_Jackson_and_the_Olympians_The_Ligh.html?hl=&id=Jcb-swEACAAJ"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "NOT_FOR_SALE",
#                         "isEbook": false
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "NO_PAGES",
#                         "embeddable": false,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": false
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=Jcb-swEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "NONE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "This deluxe gift edition of the internationally best-selling first book in the Percy Jackson and the Olympians series, lavishly illustrated by series artist John Rocco, is a must-have for Riordan fans."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "b2Wtjqjy8CwC",
#                     "etag": "+qBnZX3/KK0",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/b2Wtjqjy8CwC",
#                     "volumeInfo": {
#                         "title": "Percy Jackson and the Olympians: The Lightning Thief: The Graphic Novel",
#                         "authors": [
#                             "Rick Riordan",
#                             "Robert Venditti"
#                         ],
#                         "publisher": "Disney Electronic Content",
#                         "publishedDate": "2013-07-02",
#                         "description": "You've read the book. You've seen the movie. Now submerge yourself in the thrilling, stunning, and action-packed graphic novel. Mythological monsters and the gods of Mount Olympus seem to be walking out of the pages of twelve-year-old Percy Jackson's textbooks and into his life. And worse, he's angered a few of them. Zeus's master lightning bolt has been stolen, and Percy is the prime suspect. Now, he and his friends have just ten days to find and return Zeus's stolen property and bring peace to a warring Mount Olympus. Series creator Rick Riordan joins forces with some of the biggest names in the comic book industry to tell the story of a boy who must unravel a treachery more powerful than the gods themselves.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423147343"
#                             },
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423147340"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": true,
#                             "image": true
#                         },
#                         "pageCount": 128,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 3,
#                         "ratingsCount": 2,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": true,
#                         "contentVersion": "1.6.8.0.preview.3",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=b2Wtjqjy8CwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=b2Wtjqjy8CwC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=b2Wtjqjy8CwC&printsec=frontcover&dq=:Percy+Jackson+the+Olympians+The+Lightning+Thief&hl=&cd=3&source=gbs_api",
#                         "infoLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC&source=gbs_api",
#                         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC",
#                         "seriesInfo": {
#                             "kind": "books#volume_series_info",
#                             "bookDisplayNumber": "1",
#                             "volumeSeries": [
#                                 {
#                                     "seriesId": "ZaIqGwAAABBOuM",
#                                     "seriesBookType": "COLLECTED_EDITION",
#                                     "orderNumber": 1
#                                 }
#                             ]
#                         }
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "FOR_SALE",
#                         "isEbook": true,
#                         "listPrice": {
#                             "amount": 7.99,
#                             "currencyCode": "USD"
#                         },
#                         "retailPrice": {
#                             "amount": 7.99,
#                             "currencyCode": "USD"
#                         },
#                         "buyLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC&rdid=book-b2Wtjqjy8CwC&rdot=1&source=gbs_api",
#                         "offers": [
#                             {
#                                 "finskyOfferType": 1,
#                                 "listPrice": {
#                                     "amountInMicros": 7990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "retailPrice": {
#                                     "amountInMicros": 7990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "giftable": true
#                             }
#                         ]
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "PARTIAL",
#                         "embeddable": true,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Percy_Jackson_and_the_Olympians_The_Ligh-sample-epub.acsm?id=b2Wtjqjy8CwC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "pdf": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Percy_Jackson_and_the_Olympians_The_Ligh-sample-pdf.acsm?id=b2Wtjqjy8CwC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=b2Wtjqjy8CwC&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "SAMPLE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "You&#39;ve read the book."
#                     }
#                 }
#             ]
#         },
#         "Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson": {
#             "kind": "books#volumes",
#             "totalItems": 564,
#             "items": [
#                 {
#                     "kind": "books#volume",
#                     "id": "UevuQwAACAAJ",
#                     "etag": "yFBIRK9sxKY",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/UevuQwAACAAJ",
#                     "volumeInfo": {
#                         "title": "The Percy Jackson and the Olympians: Lightning Thief: The Graphic Novel",
#                         "authors": [
#                             "Rick Riordan",
#                             "Robert Venditti"
#                         ],
#                         "publisher": "Hyperion",
#                         "publishedDate": "2010-10-12",
#                         "description": "You've read the book. You've seen the movie. Now submerge yourself in the thrilling, stunning, and action-packed graphic novel. Mythological monsters and the gods of Mount Olympus seem to be walking out of the pages of twelve-year-old Percy Jackson's textbooks and into his life. And worse, he's angered a few of them. Zeus's master lightning bolt has been stolen, and Percy is the prime suspect. Now, he and his friends have just ten days to find and return Zeus's stolen property and bring peace to a warring Mount Olympus. Series creator Rick Riordan joins forces with some of the biggest names in the comic book industry to tell the story of a boy who must unravel a treachery more powerful than the gods themselves.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423117107"
#                             },
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423117100"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": false,
#                             "image": false
#                         },
#                         "pageCount": 128,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 5,
#                         "ratingsCount": 1,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": false,
#                         "contentVersion": "preview-1.0.0",
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=UevuQwAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=UevuQwAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=UevuQwAACAAJ&dq=:Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson&hl=&cd=1&source=gbs_api",
#                         "infoLink": "http://books.google.com/books?id=UevuQwAACAAJ&dq=:Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson&hl=&source=gbs_api",
#                         "canonicalVolumeLink": "https://books.google.com/books/about/The_Percy_Jackson_and_the_Olympians_Ligh.html?hl=&id=UevuQwAACAAJ"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "NOT_FOR_SALE",
#                         "isEbook": false
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "NO_PAGES",
#                         "embeddable": false,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": false
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=UevuQwAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "NONE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "You&#39;ve read the book."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "b2Wtjqjy8CwC",
#                     "etag": "71+3hdkBshU",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/b2Wtjqjy8CwC",
#                     "volumeInfo": {
#                         "title": "Percy Jackson and the Olympians: The Lightning Thief: The Graphic Novel",
#                         "authors": [
#                             "Rick Riordan",
#                             "Robert Venditti"
#                         ],
#                         "publisher": "Disney Electronic Content",
#                         "publishedDate": "2013-07-02",
#                         "description": "You've read the book. You've seen the movie. Now submerge yourself in the thrilling, stunning, and action-packed graphic novel. Mythological monsters and the gods of Mount Olympus seem to be walking out of the pages of twelve-year-old Percy Jackson's textbooks and into his life. And worse, he's angered a few of them. Zeus's master lightning bolt has been stolen, and Percy is the prime suspect. Now, he and his friends have just ten days to find and return Zeus's stolen property and bring peace to a warring Mount Olympus. Series creator Rick Riordan joins forces with some of the biggest names in the comic book industry to tell the story of a boy who must unravel a treachery more powerful than the gods themselves.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423147343"
#                             },
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423147340"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": true,
#                             "image": true
#                         },
#                         "pageCount": 128,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 3,
#                         "ratingsCount": 2,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": true,
#                         "contentVersion": "1.6.8.0.preview.3",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=b2Wtjqjy8CwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=b2Wtjqjy8CwC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=b2Wtjqjy8CwC&printsec=frontcover&dq=:Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson&hl=&cd=2&source=gbs_api",
#                         "infoLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC&source=gbs_api",
#                         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC",
#                         "seriesInfo": {
#                             "kind": "books#volume_series_info",
#                             "bookDisplayNumber": "1",
#                             "volumeSeries": [
#                                 {
#                                     "seriesId": "ZaIqGwAAABBOuM",
#                                     "seriesBookType": "COLLECTED_EDITION",
#                                     "orderNumber": 1
#                                 }
#                             ]
#                         }
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "FOR_SALE",
#                         "isEbook": true,
#                         "listPrice": {
#                             "amount": 7.99,
#                             "currencyCode": "USD"
#                         },
#                         "retailPrice": {
#                             "amount": 7.99,
#                             "currencyCode": "USD"
#                         },
#                         "buyLink": "https://play.google.com/store/books/details?id=b2Wtjqjy8CwC&rdid=book-b2Wtjqjy8CwC&rdot=1&source=gbs_api",
#                         "offers": [
#                             {
#                                 "finskyOfferType": 1,
#                                 "listPrice": {
#                                     "amountInMicros": 7990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "retailPrice": {
#                                     "amountInMicros": 7990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "giftable": true
#                             }
#                         ]
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "PARTIAL",
#                         "embeddable": true,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Percy_Jackson_and_the_Olympians_The_Ligh-sample-epub.acsm?id=b2Wtjqjy8CwC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "pdf": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Percy_Jackson_and_the_Olympians_The_Ligh-sample-pdf.acsm?id=b2Wtjqjy8CwC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=b2Wtjqjy8CwC&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "SAMPLE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "You&#39;ve read the book."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "e3_VPwAACAAJ",
#                     "etag": "0h7VkUtitQg",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/e3_VPwAACAAJ",
#                     "volumeInfo": {
#                         "title": "Percy Jackson and the Lightning Thief",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Puffin Books",
#                         "publishedDate": "2009-12-01",
#                         "description": "Look, I didn't want to be a half-blood. I never asked to be the son of a Greek god. I was just a normal kid, going to school, playing basketball, skateboarding. The usual. Until I accidentally vaporized my maths teacher. That's when things started really going wrong. Now I spend my time fighting with swords, battling monsters with my friends and generally trying to stay alive. This is the one where Zeus, God of the Sky, thinks I've stolen his lightning bolt - and making Zeus angry is a very bad idea. Can Percy find the lightning bolt before a fully fledged WAR OF THE GODS ERUPTS? Follow the author on his blog Also available: Percy Jackson and the Battle of the Labyrinth Percy Jackson and the Last Olympian Percy Jackson and the Lightning Thief (audio) Percy Jackson and the Lightning Thief (film tie-in) Percy Jackson and the Sea of Monsters Percy Jackson and the Titan's Curse Percy Jackson: The Demigod Files",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "0141329998"
#                             },
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9780141329994"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": false,
#                             "image": false
#                         },
#                         "pageCount": 374,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Children's stories"
#                         ],
#                         "averageRating": 4,
#                         "ratingsCount": 688,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": false,
#                         "contentVersion": "preview-1.0.0",
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=e3_VPwAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=e3_VPwAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=e3_VPwAACAAJ&dq=:Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson&hl=&cd=3&source=gbs_api",
#                         "infoLink": "http://books.google.com/books?id=e3_VPwAACAAJ&dq=:Percy+Jackson+and+the+Lightning+Thief+The+Graphic+Novel+Book+1+of+Percy+Jackson&hl=&source=gbs_api",
#                         "canonicalVolumeLink": "https://books.google.com/books/about/Percy_Jackson_and_the_Lightning_Thief.html?hl=&id=e3_VPwAACAAJ"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "NOT_FOR_SALE",
#                         "isEbook": false
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "NO_PAGES",
#                         "embeddable": false,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": false
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=e3_VPwAACAAJ&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "NONE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "YA. Fantasy fiction."
#                     }
#                 }
#             ]
#         },
#         "Percy+Jackson+the+Olympians": {
#             "kind": "books#volumes",
#             "totalItems": 1122,
#             "items": [
#                 {
#                     "kind": "books#volume",
#                     "id": "LA-dKVg8alsC",
#                     "etag": "KwAyIQL9MqQ",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/LA-dKVg8alsC",
#                     "volumeInfo": {
#                         "title": "Last Olympian, The (Percy Jackson and the Olympians, Book 5)",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Disney Electronic Content",
#                         "publishedDate": "2009-05-02",
#                         "description": "All year the half-bloods have been preparing for battle against the Titans, knowing the odds of victory are grim. Kronos's army is stronger than ever, and with every god and half-blood he recruits, the evil Titan's power only grows. While the Olympians struggle to contain the rampaging monster Typhon, Kronos begins his advance on New York City, where Mount Olympus stands virtually unguarded. Now it's up to Percy Jackson and an army of young demigods to stop the Lord of Time.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423131991"
#                             },
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423131991"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": true,
#                             "image": false
#                         },
#                         "pageCount": 416,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 4.5,
#                         "ratingsCount": 91,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": true,
#                         "contentVersion": "0.13.12.0.preview.2",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=LA-dKVg8alsC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=LA-dKVg8alsC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=LA-dKVg8alsC&printsec=frontcover&dq=:Percy+Jackson+the+Olympians&hl=&cd=1&source=gbs_api",
#                         "infoLink": "https://play.google.com/store/books/details?id=LA-dKVg8alsC&source=gbs_api",
#                         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=LA-dKVg8alsC"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "FOR_SALE",
#                         "isEbook": true,
#                         "listPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "retailPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "buyLink": "https://play.google.com/store/books/details?id=LA-dKVg8alsC&rdid=book-LA-dKVg8alsC&rdot=1&source=gbs_api",
#                         "offers": [
#                             {
#                                 "finskyOfferType": 1,
#                                 "listPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "retailPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "giftable": true
#                             }
#                         ]
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "PARTIAL",
#                         "embeddable": true,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Last_Olympian_The_Percy_Jackson_and_the-sample-epub.acsm?id=LA-dKVg8alsC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=LA-dKVg8alsC&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "SAMPLE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "All year the half-bloods have been preparing for battle against the Titans, knowing the odds of victory are grim."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "FFTJDYx_ZiEC",
#                     "etag": "P/9RoKBx8yY",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/FFTJDYx_ZiEC",
#                     "volumeInfo": {
#                         "title": "Lightning Thief, The (Percy Jackson and the Olympians, Book 1)",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Disney Electronic Content",
#                         "publishedDate": "2009-05-02",
#                         "description": "Percy Jackson is a good kid, but he can't seem to focus on his schoolwork or control his temper. And lately, being away at boarding school is only getting worse-Percy could have sworn his pre-algebra teacher turned into a monster and tried to kill him.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781423131892"
#                             },
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1423131894"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": true,
#                             "image": false
#                         },
#                         "pageCount": 400,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "averageRating": 4,
#                         "ratingsCount": 838,
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": true,
#                         "contentVersion": "0.41.40.0.preview.2",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=FFTJDYx_ZiEC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=FFTJDYx_ZiEC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=FFTJDYx_ZiEC&printsec=frontcover&dq=:Percy+Jackson+the+Olympians&hl=&cd=2&source=gbs_api",
#                         "infoLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC&source=gbs_api",
#                         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "FOR_SALE",
#                         "isEbook": true,
#                         "listPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "retailPrice": {
#                             "amount": 5.99,
#                             "currencyCode": "USD"
#                         },
#                         "buyLink": "https://play.google.com/store/books/details?id=FFTJDYx_ZiEC&rdid=book-FFTJDYx_ZiEC&rdot=1&source=gbs_api",
#                         "offers": [
#                             {
#                                 "finskyOfferType": 1,
#                                 "listPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "retailPrice": {
#                                     "amountInMicros": 5990000,
#                                     "currencyCode": "USD"
#                                 },
#                                 "giftable": true
#                             }
#                         ]
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "PARTIAL",
#                         "embeddable": true,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": true,
#                             "acsTokenLink": "http://books.google.com/books/download/Lightning_Thief_The_Percy_Jackson_and_th-sample-epub.acsm?id=FFTJDYx_ZiEC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=FFTJDYx_ZiEC&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "SAMPLE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "Percy Jackson is a good kid, but he can&#39;t seem to focus on his schoolwork or control his temper."
#                     }
#                 },
#                 {
#                     "kind": "books#volume",
#                     "id": "Awv-nQEACAAJ",
#                     "etag": "9qF4FAPkgdI",
#                     "selfLink": "https://www.googleapis.com/books/v1/volumes/Awv-nQEACAAJ",
#                     "volumeInfo": {
#                         "title": "Percy Jackson and the Olympians 5 Book Paperback Boxed Set (new covers w/poster)",
#                         "authors": [
#                             "Rick Riordan"
#                         ],
#                         "publisher": "Disney-Hyperion",
#                         "publishedDate": "2014-06-03",
#                         "description": "All five books in the blockbuster Percy Jackson and the Olympians series, in paperback, have been collected in a boxed set fit for demigods. Now with glorious new cover art and packaged with a special poster, this value-priced set includes the best-selling The Lightning Thief, The Sea of Monsters, The Titan's Curse, The Battle of the Labyrinth, and The Last Olympian. Whether it is for readers who are experiencing Percy's thrilling adventures with Greek gods and monsters for the first time, or for fans who want to devour the saga again, this gift will be prized by young and old.",
#                         "industryIdentifiers": [
#                             {
#                                 "type": "ISBN_10",
#                                 "identifier": "1484707230"
#                             },
#                             {
#                                 "type": "ISBN_13",
#                                 "identifier": "9781484707234"
#                             }
#                         ],
#                         "readingModes": {
#                             "text": false,
#                             "image": false
#                         },
#                         "pageCount": 1840,
#                         "printType": "BOOK",
#                         "categories": [
#                             "Juvenile Fiction"
#                         ],
#                         "maturityRating": "NOT_MATURE",
#                         "allowAnonLogging": false,
#                         "contentVersion": "preview-1.0.0",
#                         "panelizationSummary": {
#                             "containsEpubBubbles": false,
#                             "containsImageBubbles": false
#                         },
#                         "imageLinks": {
#                             "smallThumbnail": "http://books.google.com/books/content?id=Awv-nQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#                             "thumbnail": "http://books.google.com/books/content?id=Awv-nQEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#                         },
#                         "language": "en",
#                         "previewLink": "http://books.google.com/books?id=Awv-nQEACAAJ&dq=:Percy+Jackson+the+Olympians&hl=&cd=3&source=gbs_api",
#                         "infoLink": "http://books.google.com/books?id=Awv-nQEACAAJ&dq=:Percy+Jackson+the+Olympians&hl=&source=gbs_api",
#                         "canonicalVolumeLink": "https://books.google.com/books/about/Percy_Jackson_and_the_Olympians_5_Book_P.html?hl=&id=Awv-nQEACAAJ"
#                     },
#                     "saleInfo": {
#                         "country": "US",
#                         "saleability": "NOT_FOR_SALE",
#                         "isEbook": false
#                     },
#                     "accessInfo": {
#                         "country": "US",
#                         "viewability": "NO_PAGES",
#                         "embeddable": false,
#                         "publicDomain": false,
#                         "textToSpeechPermission": "ALLOWED",
#                         "epub": {
#                             "isAvailable": false
#                         },
#                         "pdf": {
#                             "isAvailable": false
#                         },
#                         "webReaderLink": "http://play.google.com/books/reader?id=Awv-nQEACAAJ&hl=&printsec=frontcover&source=gbs_api",
#                         "accessViewStatus": "NONE",
#                         "quoteSharingAllowed": false
#                     },
#                     "searchInfo": {
#                         "textSnippet": "All five books in the blockbuster Percy Jackson and the Olympians series, in paperback, have been collected in a boxed set fit for demigods."
#                     }
#                 }
#             ]
#         }
#     }
# }
